# %% [markdown]
# **Проект по ТАБД**
#
# Мы анализируем данные по численности рабочей силы в Российской Федерации, чтобы понять, как изменяется численность мужчин и женщин в различных возрастных категориях в течение времени.
# Этот анализ помогает выявить тренды на рынке труда.
#
# Данная работа реализует:
# - открытие и запись файла csv
# - Запись данных в словарь
# - Расчет среднего
# - Расчет стандартного отклонения
#
# - Расчет медианы
# - расчет минимума и максимума

# %% [markdown]
# Для открытия файла используется функция read_csv, которая принимает путь до файла и требуемую кодировку.

# %%
def read_csv(file_path, encoding):
    with open(file_path, 'r', encoding=encoding) as file:
        lines = file.readlines()
        data = [line.strip().split(',') for line in lines]
    return data

# %% [markdown]
# Для записи данных в словарь используется функция csv_to_dict, принимающая на вход массив данных и требуемый заголовок категории данных. Заголовки таблицы  (т.е первый элемент массива) записываются как ключ, а их данные как значение по ключу.
# Возвращаемое значение - Словарь с одной категорией, в которой данные организованы по годам. Каждый год становится ключом, а значением является вложенный словарь с данными за этот год.

# %%
def csv_to_dict(data, category):
    headers = data[0] 
    records = {}
    for row in data[1:]:
        year = int(row[0])
        records[year] = {
            headers[i]:  float(row[i].replace(',', '.').replace('"', '')) for i in range(1, len(headers))
        }
    return {category: records}

# %% [markdown]
# Вычисление среднего значения

# %%
def calculate_mean(values):
    return sum(values) / len(values)

# %% [markdown]
# Вычисление медианы

# %%
def calculate_median(values):
    n = len(values)
    sorted_values = sorted(values)
    return sorted_values[n // 2] if n % 2 != 0 else (sorted_values[n // 2 - 1] + sorted_values[n // 2]) / 2

# %% [markdown]
# Вычисление минимума

# %%
def calculate_min(values):
    return min(values)

# %% [markdown]
# Вычисление максимума

# %%
def calculate_max(values):
    return max(values)

# %% [markdown]
# Функция для вычисления стандартного отклонения

# %%
def calculate_stddev(values, mean):
    variance = sum((x - mean) ** 2 for x in values) / len(values)
    return variance ** 0.5

# %% [markdown]
# читаем файл

# %%
men = read_csv('RabSilaMens.csv', 'utf-8')
woman = read_csv('RabSilaWomen.csv', 'utf-8')
print(all)
print(men)
print(woman)
# Out:
# [['Год', 'Всего тыс. человек', '15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70 и старше', 'Средний возраст лет'], ['2013', '75616', '686', '6972', '10779', '9927', '9508', '8634', '9173', '9914', '6553', '2606', '690', '174', '"40', '0"'], ['2014', '75582', '578', '6387', '10983', '10204', '9564', '8905', '8779', '9917', '6678', '2731', '717', '139', '"40', '2"'], ['2015', '76762', '611', '5871', '11197', '10615', '9896', '9177', '8618', '9891', '7029', '2923', '810', '124', '"40', '3"'], ['2016', '76933', '612', '5411', '11217', '10925', '10050', '9430', '8515', '9624', '7156', '3017', '848', '127', '"40', '4"'], ['2017', '76659', '540', '4779', '11103', '11081', '10324', '9565', '8611', '9148', '7291', '3011', '946', '261', '"40', '7"'], ['2018', '76630', '521', '4419', '10557', '11461', '10451', '9757', '8706', '8748', '7483', '3200', '1025', '302', '"40', '9"'], ['2019', '75880', '474', '4257', '9756', '11575', '10619', '9755', '8870', '8334', '7458', '3310', '1140', '334', '"41', '1"'], ['2020', '75466', '467', '4134', '8882', '11481', '10866', '9947', '9018', '8095', '7555', '3556', '1146', '319', '"41', '3"'], ['2021', '75969', '465', '4107', '8184', '11582', '11187', '10173', '9249', '8097', '7637', '3840', '1138', '308', '"41', '6"'], ['2022', '75632', '415', '3817', '7479', '11390', '11358', '10496', '9405', '8268', '7497', '4091', '1133', '284', '"41', '9"'], ['2023', '76037', '506', '3796', '7152', '10873', '11763', '10580', '9648', '8388', '7454', '4440', '1158', '279', '"42', '1"']]
# [['Год', 'Всего тыс. человек', '15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70 и старше', 'Средний возраст лет'], ['2013', '38760', '401', '3909', '5868', '5254', '4802', '4273', '4388', '4674', '3446', '1348', '321', '76', '"38', '8"'], ['2014', '38782', '346', '3586', '6000', '5396', '4850', '4392', '4200', '4686', '3547', '1394', '328', '59', '"39', '5"'], ['2015', '39492', '368', '3275', '6124', '5665', '5025', '4549', '4161', '4676', '3738', '1485', '372', '53', '"39', '7"'], ['2016', '39579', '380', '3033', '6108', '5807', '5113', '4658', '4105', '4557', '3849', '1527', '387', '56', '"39', '9"'], ['2017', '39416', '325', '2673', '6014', '5887', '5253', '4709', '4160', '4327', '3938', '1559', '455', '116', '"40', '0"'], ['2018', '39313', '300', '2463', '5697', '6065', '5318', '4803', '4226', '4147', '4043', '1657', '481', '114', '"40', '3"'], ['2019', '38894', '277', '2378', '5275', '6126', '5417', '4791', '4302', '3953', '3987', '1718', '538', '132', '"40', '5"'], ['2020', '38589', '284', '2307', '4794', '6077', '5538', '4886', '4360', '3837', '3969', '1858', '544', '136', '"40', '7"'], ['2021', '38892', '279', '2284', '4411', '6101', '5708', '5009', '4475', '3870', '3929', '2141', '553', '131', '"41', '0"'], ['2022', '38576', '244', '2137', '4025', '5984', '5777', '5172', '4540', '3944', '3779', '2300', '551', '123', '"41', '3"'], ['2023', '38875', '300', '2141', '3845', '5716', '6002', '5228', '4653', '4011', '3713', '2563', '582', '121', '"41', '6"']]
# [['Год', 'Всего тыс. человек', '15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70 и старше', 'Средний возраст лет'], ['2013', '36856', '285', '3063', '4911', '4673', '4706', '4361', '4785', '5240', '3106', '1257', '369', '98', '"40', '6"'], ['2014', '36800', '232', '2802', '4984', '4808', '4714', '4513', '4579', '5230', '3131', '1337', '390', '79', '"40', '7"'], ['2015', '37270', '243', '2596', '5073', '4950', '4871', '4628', '4457', '5215', '3291', '1439', '438', '70', '"40', '8"'], ['2016', '37354', '233', '2379', '5109', '5118', '4937', '4772', '4410', '5067', '3308', '1490', '461', '71', '"40', '9"'], ['2017', '37243', '215', '2106', '5088', '5194', '5070', '4856', '4451', '4821', '3353', '1452', '491', '146', '"41', '1"'], ['2018', '37317', '221', '1956', '4860', '5397', '5133', '4953', '4480', '4601', '3440', '1543', '544', '188', '"41', '3"'], ['2019', '36986', '197', '1879', '4481', '5449', '5203', '4964', '4568', '4381', '3471', '1591', '601', '202', '"41', '5"'], ['2020', '36877', '183', '1828', '4088', '5404', '5328', '5061', '4659', '4257', '3586', '1698', '602', '183', '"41', '7"'], ['2021', '37078', '186', '1823', '3773', '5482', '5480', '5164', '4773', '4227', '3708', '1700', '585', '177', '"41', '9"'], ['2022', '37056', '171', '1679', '3453', '5407', '5581', '5324', '4865', '4324', '3718', '1791', '582', '161', '"42', '2"'], ['2023', '37161', '207', '1655', '3306', '5157', '5761', '5351', '4995', '4376', '3742', '1877', '575', '158', '"42', '4"']]

# %% [markdown]
# Создаем словари

# %%
dictMan = csv_to_dict(men, 'men')
dictWoman = csv_to_dict(woman, 'woman')
dictWoman
# Out:
# {'woman': {2013: {'Всего тыс. человек': 36856.0,
#    '15-19': 285.0,
#    '20-24': 3063.0,
#    '25-29': 4911.0,
#    '30-34': 4673.0,
#    '35-39': 4706.0,
#    '40-44': 4361.0,
#    '45-49': 4785.0,
#    '50-54': 5240.0,
#    '55-59': 3106.0,
#    '60-64': 1257.0,
#    '65-69': 369.0,
#    '70 и старше': 98.0,
#    'Средний возраст лет': 40.0},
#   2014: {'Всего тыс. человек': 36800.0,
#    '15-19': 232.0,
#    '20-24': 2802.0,
#    '25-29': 4984.0,
#    '30-34': 4808.0,
#    '35-39': 4714.0,
#    '40-44': 4513.0,
#    '45-49': 4579.0,
#    '50-54': 5230.0,
#    '55-59': 3131.0,
#    '60-64': 1337.0,
#    '65-69': 390.0,
#    '70 и старше': 79.0,
#    'Средний возраст лет': 40.0},
#   2015: {'Всего тыс. человек': 37270.0,
#    '15-19': 243.0,
#    '20-24': 2596.0,
#    '25-29': 5073.0,
#    '30-34': 4950.0,
#    '35-39': 4871.0,
#    '40-44': 4628.0,
#    '45-49': 4457.0,
#    '50-54': 5215.0,
#    '55-59': 3291.0,
#    '60-64': 1439.0,
#    '65-69': 438.0,
#    '70 и старше': 70.0,
#    'Средний возраст лет': 40.0},
#   2016: {'Всего тыс. человек': 37354.0,
#    '15-19': 233.0,
#    '20-24': 2379.0,
#    '25-29': 5109.0,
#    '30-34': 5118.0,
#    '35-39': 4937.0,
#    '40-44': 4772.0,
#    '45-49': 4410.0,
#    '50-54': 5067.0,
#    '55-59': 3308.0,
#    '60-64': 1490.0,
#    '65-69': 461.0,
#    '70 и старше': 71.0,
#    'Средний возраст лет': 40.0},
#   2017: {'Всего тыс. человек': 37243.0,
#    '15-19': 215.0,
#    '20-24': 2106.0,
#    '25-29': 5088.0,
#    '30-34': 5194.0,
#    '35-39': 5070.0,
#    '40-44': 4856.0,
#    '45-49': 4451.0,
#    '50-54': 4821.0,
#    '55-59': 3353.0,
#    '60-64': 1452.0,
#    '65-69': 491.0,
#    '70 и старше': 146.0,
#    'Средний возраст лет': 41.0},
#   2018: {'Всего тыс. человек': 37317.0,
#    '15-19': 221.0,
#    '20-24': 1956.0,
#    '25-29': 4860.0,
#    '30-34': 5397.0,
#    '35-39': 5133.0,
#    '40-44': 4953.0,
#    '45-49': 4480.0,
#    '50-54': 4601.0,
#    '55-59': 3440.0,
#    '60-64': 1543.0,
#    '65-69': 544.0,
#    '70 и старше': 188.0,
#    'Средний возраст лет': 41.0},
#   2019: {'Всего тыс. человек': 36986.0,
#    '15-19': 197.0,
#    '20-24': 1879.0,
#    '25-29': 4481.0,
#    '30-34': 5449.0,
#    '35-39': 5203.0,
#    '40-44': 4964.0,
#    '45-49': 4568.0,
#    '50-54': 4381.0,
#    '55-59': 3471.0,
#    '60-64': 1591.0,
#    '65-69': 601.0,
#    '70 и старше': 202.0,
#    'Средний возраст лет': 41.0},
#   2020: {'Всего тыс. человек': 36877.0,
#    '15-19': 183.0,
#    '20-24': 1828.0,
#    '25-29': 4088.0,
#    '30-34': 5404.0,
#    '35-39': 5328.0,
#    '40-44': 5061.0,
#    '45-49': 4659.0,
#    '50-54': 4257.0,
#    '55-59': 3586.0,
#    '60-64': 1698.0,
#    '65-69': 602.0,
#    '70 и старше': 183.0,
#    'Средний возраст лет': 41.0},
#   2021: {'Всего тыс. человек': 37078.0,
#    '15-19': 186.0,
#    '20-24': 1823.0,
#    '25-29': 3773.0,
#    '30-34': 5482.0,
#    '35-39': 5480.0,
#    '40-44': 5164.0,
#    '45-49': 4773.0,
#    '50-54': 4227.0,
#    '55-59': 3708.0,
#    '60-64': 1700.0,
#    '65-69': 585.0,
#    '70 и старше': 177.0,
#    'Средний возраст лет': 41.0},
#   2022: {'Всего тыс. человек': 37056.0,
#    '15-19': 171.0,
#    '20-24': 1679.0,
#    '25-29': 3453.0,
#    '30-34': 5407.0,
#    '35-39': 5581.0,
#    '40-44': 5324.0,
#    '45-49': 4865.0,
#    '50-54': 4324.0,
#    '55-59': 3718.0,
#    '60-64': 1791.0,
#    '65-69': 582.0,
#    '70 и старше': 161.0,
#    'Средний возраст лет': 42.0},
#   2023: {'Всего тыс. человек': 37161.0,
#    '15-19': 207.0,
#    '20-24': 1655.0,
#    '25-29': 3306.0,
#    '30-34': 5157.0,
#    '35-39': 5761.0,
#    '40-44': 5351.0,
#    '45-49': 4995.0,
#    '50-54': 4376.0,
#    '55-59': 3742.0,
#    '60-64': 1877.0,
#    '65-69': 575.0,
#    '70 и старше': 158.0,
#    'Средний возраст лет': 42.0}}}

# %% [markdown]
# Отдельно выписаны все возрастные категории для удобства

# %%
age_categories = ['15-19', '20-24', '25-29', '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70 и старше']

# %% [markdown]
# Функция для подсчета всех статистик

# %%
def calculate_statistics(data, key):
    for category in age_categories:
        values = [data[key][year][category] for year in range(2013, 2024)]
        mean_value = calculate_mean(values)
        median_value = calculate_median(values)
        min_value = calculate_min(values)
        max_value = calculate_max(values)
        stddev = calculate_stddev(values, mean_value)
        print(f"Категория {category}: Среднее = {mean_value}, медиана = {median_value}, минимальное = {min_value}, максимальное = {max_value}, стандартное отклонение = {stddev}")

# %%
print("Данные для женщин за все года")
calculate_statistics(dictWoman, 'woman')
# Out:
# Данные для женщин за все года
# Категория 15-19: Среднее = 215.72727272727272, медиана = 215.0, минимальное = 171.0, максимальное = 285.0, стандартное отклонение = 30.91951695815476
# Категория 20-24: Среднее = 2160.5454545454545, медиана = 1956.0, минимальное = 1655.0, максимальное = 3063.0, стандартное отклонение = 457.1948786073542
# Категория 25-29: Среднее = 4466.0, медиана = 4860.0, минимальное = 3306.0, максимальное = 5109.0, стандартное отклонение = 659.5793425289403
# Категория 30-34: Среднее = 5185.363636363636, медиана = 5194.0, минимальное = 4673.0, максимальное = 5482.0, стандартное отклонение = 263.70516343663144
# Категория 35-39: Среднее = 5162.181818181818, медиана = 5133.0, минимальное = 4706.0, максимальное = 5761.0, стандартное отклонение = 332.75347636509804
# Категория 40-44: Среднее = 4904.272727272727, медиана = 4953.0, минимальное = 4361.0, максимальное = 5351.0, стандартное отклонение = 304.2266173607165
# Категория 45-49: Среднее = 4638.363636363636, медиана = 4579.0, минимальное = 4410.0, максимальное = 4995.0, стандартное отклонение = 183.9739471314906
# Категория 50-54: Среднее = 4703.545454545455, медиана = 4601.0, минимальное = 4227.0, максимальное = 5240.0, стандартное отклонение = 400.54607353560885
# Категория 55-59: Среднее = 3441.2727272727275, медиана = 3440.0, минимальное = 3106.0, максимальное = 3742.0, стандартное отклонение = 216.7533541353527
# Категория 60-64: Среднее = 1561.3636363636363, медиана = 1543.0, минимальное = 1257.0, максимальное = 1877.0, стандартное отклонение = 182.5243558976932
# Категория 65-69: Среднее = 512.5454545454545, медиана = 544.0, минимальное = 369.0, максимальное = 602.0, стандартное отклонение = 82.62221100930498
# Категория 70 и старше: Среднее = 139.36363636363637, медиана = 158.0, минимальное = 70.0, максимальное = 202.0, стандартное отклонение = 47.96641386954139
# None

# %%
print("Данные для мужчин за все года")
calculate_statistics(dictMan, 'men')
# Out:
# Данные для мужчин за все года
# Категория 15-19: Среднее = 318.54545454545456, медиана = 300.0, минимальное = 244.0, максимальное = 401.0, стандартное отклонение = 47.237049473640994
# Категория 20-24: Среднее = 2744.181818181818, медиана = 2463.0, минимальное = 2137.0, максимальное = 3909.0, стандартное отклонение = 586.5349432637594
# Категория 25-29: Среднее = 5287.363636363636, медиана = 5697.0, минимальное = 3845.0, максимальное = 6124.0, стандартное отклонение = 831.1954449878772
# Категория 30-34: Среднее = 5825.272727272727, медиана = 5887.0, минимальное = 5254.0, максимальное = 6126.0, стандартное отклонение = 280.40428310471844
# Категория 35-39: Среднее = 5345.727272727273, медиана = 5318.0, минимальное = 4802.0, максимальное = 6002.0, стандартное отклонение = 368.9986673809617
# Категория 40-44: Среднее = 4770.0, медиана = 4791.0, минимальное = 4273.0, максимальное = 5228.0, стандартное отклонение = 285.79617657599016
# Категория 45-49: Среднее = 4324.545454545455, медиана = 4302.0, минимальное = 4105.0, максимальное = 4653.0, стандартное отклонение = 167.86811037042992
# Категория 50-54: Среднее = 4243.818181818182, медиана = 4147.0, минимальное = 3837.0, максимальное = 4686.0, стандартное отклонение = 332.43586344704914
# Категория 55-59: Среднее = 3812.5454545454545, медиана = 3849.0, минимальное = 3446.0, максимальное = 4043.0, стандартное отклонение = 180.93512832271412
# Категория 60-64: Среднее = 1777.2727272727273, медиана = 1657.0, минимальное = 1348.0, максимальное = 2563.0, стандартное отклонение = 378.3072562947865
# Категория 65-69: Среднее = 464.72727272727275, медиана = 481.0, минимальное = 321.0, максимальное = 582.0, стандартное отклонение = 92.928213652055
# Категория 70 и старше: Среднее = 101.54545454545455, медиана = 116.0, минимальное = 53.0, максимальное = 136.0, стандартное отклонение = 31.735737344410143

# %% [markdown]
# Функция для сортироввки и добавления ранга

# %%
def sort_data(data):
    sorted_and_ranked_data = {} 
    for key in data: 
        sorted_and_ranked_data[key] = {} 
        
        for year in data[key]:
            filtered_age_data = {}
            for age_category in data[key][year]:
                if age_category != 'Всего тыс. человек' and age_category != 'Средний возраст лет':
                    filtered_age_data[age_category] = data[key][year][age_category]
        
            sorted_age_data = {}
            for age_category in sorted(filtered_age_data, key=lambda x: filtered_age_data[x]):
                sorted_age_data[age_category] = filtered_age_data[age_category]
            
            ranked_age_data = {}
            rank = 1
            for age_category in sorted_age_data:
                ranked_age_data[age_category] = {"value": sorted_age_data[age_category], "rank": rank}
                rank += 1
        
            sorted_and_ranked_data[key][year] = ranked_age_data
    
    return sorted_and_ranked_data

# %%
sorted_data_man = sort_data(dictMan)
sorted_data_woman = sort_data(dictWoman)
sorted_data_man
# Out:
# {'men': {2013: {'70 и старше': {'value': 76.0, 'rank': 1},
#    '65-69': {'value': 321.0, 'rank': 2},
#    '15-19': {'value': 401.0, 'rank': 3},
#    '60-64': {'value': 1348.0, 'rank': 4},
#    '55-59': {'value': 3446.0, 'rank': 5},
#    '20-24': {'value': 3909.0, 'rank': 6},
#    '40-44': {'value': 4273.0, 'rank': 7},
#    '45-49': {'value': 4388.0, 'rank': 8},
#    '50-54': {'value': 4674.0, 'rank': 9},
#    '35-39': {'value': 4802.0, 'rank': 10},
#    '30-34': {'value': 5254.0, 'rank': 11},
#    '25-29': {'value': 5868.0, 'rank': 12}},
#   2014: {'70 и старше': {'value': 59.0, 'rank': 1},
#    '65-69': {'value': 328.0, 'rank': 2},
#    '15-19': {'value': 346.0, 'rank': 3},
#    '60-64': {'value': 1394.0, 'rank': 4},
#    '55-59': {'value': 3547.0, 'rank': 5},
#    '20-24': {'value': 3586.0, 'rank': 6},
#    '45-49': {'value': 4200.0, 'rank': 7},
#    '40-44': {'value': 4392.0, 'rank': 8},
#    '50-54': {'value': 4686.0, 'rank': 9},
#    '35-39': {'value': 4850.0, 'rank': 10},
#    '30-34': {'value': 5396.0, 'rank': 11},
#    '25-29': {'value': 6000.0, 'rank': 12}},
#   2015: {'70 и старше': {'value': 53.0, 'rank': 1},
#    '15-19': {'value': 368.0, 'rank': 2},
#    '65-69': {'value': 372.0, 'rank': 3},
#    '60-64': {'value': 1485.0, 'rank': 4},
#    '20-24': {'value': 3275.0, 'rank': 5},
#    '55-59': {'value': 3738.0, 'rank': 6},
#    '45-49': {'value': 4161.0, 'rank': 7},
#    '40-44': {'value': 4549.0, 'rank': 8},
#    '50-54': {'value': 4676.0, 'rank': 9},
#    '35-39': {'value': 5025.0, 'rank': 10},
#    '30-34': {'value': 5665.0, 'rank': 11},
#    '25-29': {'value': 6124.0, 'rank': 12}},
#   2016: {'70 и старше': {'value': 56.0, 'rank': 1},
#    '15-19': {'value': 380.0, 'rank': 2},
#    '65-69': {'value': 387.0, 'rank': 3},
#    '60-64': {'value': 1527.0, 'rank': 4},
#    '20-24': {'value': 3033.0, 'rank': 5},
#    '55-59': {'value': 3849.0, 'rank': 6},
#    '45-49': {'value': 4105.0, 'rank': 7},
#    '50-54': {'value': 4557.0, 'rank': 8},
#    '40-44': {'value': 4658.0, 'rank': 9},
#    '35-39': {'value': 5113.0, 'rank': 10},
#    '30-34': {'value': 5807.0, 'rank': 11},
#    '25-29': {'value': 6108.0, 'rank': 12}},
#   2017: {'70 и старше': {'value': 116.0, 'rank': 1},
#    '15-19': {'value': 325.0, 'rank': 2},
#    '65-69': {'value': 455.0, 'rank': 3},
#    '60-64': {'value': 1559.0, 'rank': 4},
#    '20-24': {'value': 2673.0, 'rank': 5},
#    '55-59': {'value': 3938.0, 'rank': 6},
#    '45-49': {'value': 4160.0, 'rank': 7},
#    '50-54': {'value': 4327.0, 'rank': 8},
#    '40-44': {'value': 4709.0, 'rank': 9},
#    '35-39': {'value': 5253.0, 'rank': 10},
#    '30-34': {'value': 5887.0, 'rank': 11},
#    '25-29': {'value': 6014.0, 'rank': 12}},
#   2018: {'70 и старше': {'value': 114.0, 'rank': 1},
#    '15-19': {'value': 300.0, 'rank': 2},
#    '65-69': {'value': 481.0, 'rank': 3},
#    '60-64': {'value': 1657.0, 'rank': 4},
#    '20-24': {'value': 2463.0, 'rank': 5},
#    '55-59': {'value': 4043.0, 'rank': 6},
#    '50-54': {'value': 4147.0, 'rank': 7},
#    '45-49': {'value': 4226.0, 'rank': 8},
#    '40-44': {'value': 4803.0, 'rank': 9},
#    '35-39': {'value': 5318.0, 'rank': 10},
#    '25-29': {'value': 5697.0, 'rank': 11},
#    '30-34': {'value': 6065.0, 'rank': 12}},
#   2019: {'70 и старше': {'value': 132.0, 'rank': 1},
#    '15-19': {'value': 277.0, 'rank': 2},
#    '65-69': {'value': 538.0, 'rank': 3},
#    '60-64': {'value': 1718.0, 'rank': 4},
#    '20-24': {'value': 2378.0, 'rank': 5},
#    '50-54': {'value': 3953.0, 'rank': 6},
#    '55-59': {'value': 3987.0, 'rank': 7},
#    '45-49': {'value': 4302.0, 'rank': 8},
#    '40-44': {'value': 4791.0, 'rank': 9},
#    '25-29': {'value': 5275.0, 'rank': 10},
#    '35-39': {'value': 5417.0, 'rank': 11},
#    '30-34': {'value': 6126.0, 'rank': 12}},
#   2020: {'70 и старше': {'value': 136.0, 'rank': 1},
#    '15-19': {'value': 284.0, 'rank': 2},
#    '65-69': {'value': 544.0, 'rank': 3},
#    '60-64': {'value': 1858.0, 'rank': 4},
#    '20-24': {'value': 2307.0, 'rank': 5},
#    '50-54': {'value': 3837.0, 'rank': 6},
#    '55-59': {'value': 3969.0, 'rank': 7},
#    '45-49': {'value': 4360.0, 'rank': 8},
#    '25-29': {'value': 4794.0, 'rank': 9},
#    '40-44': {'value': 4886.0, 'rank': 10},
#    '35-39': {'value': 5538.0, 'rank': 11},
#    '30-34': {'value': 6077.0, 'rank': 12}},
#   2021: {'70 и старше': {'value': 131.0, 'rank': 1},
#    '15-19': {'value': 279.0, 'rank': 2},
#    '65-69': {'value': 553.0, 'rank': 3},
#    '60-64': {'value': 2141.0, 'rank': 4},
#    '20-24': {'value': 2284.0, 'rank': 5},
#    '50-54': {'value': 3870.0, 'rank': 6},
#    '55-59': {'value': 3929.0, 'rank': 7},
#    '25-29': {'value': 4411.0, 'rank': 8},
#    '45-49': {'value': 4475.0, 'rank': 9},
#    '40-44': {'value': 5009.0, 'rank': 10},
#    '35-39': {'value': 5708.0, 'rank': 11},
#    '30-34': {'value': 6101.0, 'rank': 12}},
#   2022: {'70 и старше': {'value': 123.0, 'rank': 1},
#    '15-19': {'value': 244.0, 'rank': 2},
#    '65-69': {'value': 551.0, 'rank': 3},
#    '20-24': {'value': 2137.0, 'rank': 4},
#    '60-64': {'value': 2300.0, 'rank': 5},
#    '55-59': {'value': 3779.0, 'rank': 6},
#    '50-54': {'value': 3944.0, 'rank': 7},
#    '25-29': {'value': 4025.0, 'rank': 8},
#    '45-49': {'value': 4540.0, 'rank': 9},
#    '40-44': {'value': 5172.0, 'rank': 10},
#    '35-39': {'value': 5777.0, 'rank': 11},
#    '30-34': {'value': 5984.0, 'rank': 12}},
#   2023: {'70 и старше': {'value': 121.0, 'rank': 1},
#    '15-19': {'value': 300.0, 'rank': 2},
#    '65-69': {'value': 582.0, 'rank': 3},
#    '20-24': {'value': 2141.0, 'rank': 4},
#    '60-64': {'value': 2563.0, 'rank': 5},
#    '55-59': {'value': 3713.0, 'rank': 6},
#    '25-29': {'value': 3845.0, 'rank': 7},
#    '50-54': {'value': 4011.0, 'rank': 8},
#    '45-49': {'value': 4653.0, 'rank': 9},
#    '40-44': {'value': 5228.0, 'rank': 10},
#    '30-34': {'value': 5716.0, 'rank': 11},
#    '35-39': {'value': 6002.0, 'rank': 12}}}}

# %% [markdown]
# Функция для записи данных в файл

# %%
def write_data_to_csv(man_data, woman_data, filename):
    with open(filename, 'w', encoding='utf-8') as file:
        file.write('Пол,Год,Возрастная категория,Значение,Рейтинг\n')

        for key, data in man_data.items():
            for year, age_data in data.items():
                for age_category, info in age_data.items():
                    value = info['value']
                    rank = info['rank']
                    file.write(f"{key},{year},{age_category},{value},{rank}\n")
        

        for key, data in woman_data.items():
            for year, age_data in data.items():
                for age_category, info in age_data.items():
                    value = info['value']
                    rank = info['rank']
                    file.write(f"{key},{year},{age_category},{value},{rank}\n")

# %% [markdown]
# По итогам работы функции мы получаем единый файл со всеми данные, которые отсортированы внутри каждого года для каждого гендера

# %%
filename = 'gender_ranked_data.csv'
write_data_to_csv(sorted_data_man, sorted_data_woman, filename)
